# %%
import pandas as pd
import numpy as np
from matplotlib import ticker
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import ScalarFormatter

# %% [markdown]
# ## read()

# %%
df1 = pd.read_csv('data/osblock_r_fscache_nocpucache_8.0MiB_1639676269.csv', header=None)
df1 = df1.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df2 = pd.read_csv('data/osblock_r_fscache_nocpucache_8.0MiB_1639676269.csv', header=None)
df2 = df2.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df3 = pd.read_csv('data/osblock_r_nofscache_cpucache_8.0MiB_1639676345.csv', header=None)
df3 = df3.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df4 = pd.read_csv('data/osblock_r_nofscache_nocpucache_8.0MiB_1639676435.csv', header=None)
df4 = df4.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df5 = pd.read_csv('data/osblock_r_fscache_cpucache_100.0MiB_1639676631.csv', header=None)
df5 = df5.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df6 = pd.read_csv('data/osblock_r_fscache_nocpucache_100.0MiB_1639676788.csv', header=None)
df6 = df6.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df7 = pd.read_csv('data/osblock_r_nofscache_cpucache_100.0MiB_1639677544.csv', header=None)
df7 = df7.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df8 = pd.read_csv('data/osblock_r_nofscache_nocpucache_100.0MiB_1639678333.csv', header=None)
df8 = df8.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df9 = pd.read_csv('data/osblock_r_fscache_cpucache_2.0GiB_1639701582.csv', header=None)
df9 = df9.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df10 = pd.read_csv('data/osblock_r_fscache_nocpucache_2.0GiB_1639702831.csv', header=None)
df10 = df10.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

# %%
fig , (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24,8))

data = [df1, df2, df3, df4]
labels = ['FS + CPU caching', 'FS + No CPU caching', 'No FS + CPU caching', 'No FS + No CPU caching']

for idx, d in enumerate(data):
    ax1.plot(d['Block size'], d['Mean'], label=labels[idx])
ax1.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax1.set_xscale('log')
ax1.set_xlabel('Block size (bytes)')
ax1.set_ylabel('MiB/s')
ax1.set_title('read() syscall with variable block sizes, 8 MiB file')
ax1.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax1.xaxis.set_major_formatter(formatter)
ax1.set_xticks(df1['Block size'], df1['Block size'])
ax1.legend()

data = [df5, df6, df7, df8]
for idx, d in enumerate(data):
    ax2.plot(d['Block size'], d['Mean'], label=labels[idx])
ax2.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax2.set_xscale('log')
ax2.set_xlabel('Block size (bytes)')
ax2.set_ylabel('MiB/s')
ax2.set_title('read() syscall with variable block sizes, 100 MiB file')
ax2.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax2.xaxis.set_major_formatter(formatter)
ax2.set_xticks(df5['Block size'], df5['Block size'])
ax2.legend()

data = [df9, df10]
for idx, d in enumerate(data):
    ax3.plot(d['Block size'], d['Mean'], label=labels[idx])
ax3.set_xticks(df9['Block size'], df9['Block size'], rotation="vertical")
ax3.set_xscale('log')
ax3.set_xlabel('Block size (bytes)')
ax3.set_ylabel('MiB/s')
ax3.set_title('read() syscall with variable block sizes, 2 GB file')
ax3.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax3.xaxis.set_major_formatter(formatter)
ax3.set_xticks(df9['Block size'], df9['Block size'])
ax3.legend()

# %% [markdown]
# ## fread()

# %%
df1 = pd.read_csv('data/stdioblock_r_fscache_cpucache_8.0MiB_1639679394.csv', header=None)
df1 = df1.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df2 = pd.read_csv('data/stdioblock_r_fscache_nocpucache_8.0MiB_1639679421.csv', header=None)
df2 = df2.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df3 = pd.read_csv('data/stdioblock_r_nofscache_cpucache_8.0MiB_1639679471.csv', header=None)
df3 = df3.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df4 = pd.read_csv('data/stdioblock_r_nofscache_nocpucache_8.0MiB_1639679903.csv', header=None)
df4 = df4.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df5 = pd.read_csv('data/stdioblock_r_fscache_cpucache_100.0MiB_1639680417.csv', header=None)
df5 = df5.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df6= pd.read_csv('data/stdioblock_r_fscache_nocpucache_100.0MiB_1639680467.csv', header=None)
df6 = df6.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df7 = pd.read_csv('data/stdioblock_r_nofscache_cpucache_100.0MiB_1639681032.csv', header=None)
df7 = df7.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df8 = pd.read_csv('data/stdioblock_r_nofscache_nocpucache_100.0MiB_1639681160.csv', header=None)
df8 = df8.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df9 = pd.read_csv('data/stdioblock_r_fscache_nocpucache_2.0GiB_1639686264.csv', header=None)
df9 = df9.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df10 = pd.read_csv('data/stdioblock_r_nofscache_cpucache_2.0GiB_1639687373.csv', header=None)
df10 = df10.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df11 = pd.read_csv('data/stdioblock_r_nofscache_nocpucache_2.0GiB_1639688876.csv', header=None)
df11 = df11.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df12 = pd.read_csv('data/stdioblock_r_nofscache_nocpucache_2.0GiB_1639688876.csv', header=None)
df12 = df12.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

fig , (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24,8))

data = [df1, df2, df3, df4]
labels = ['FS + CPU caching', 'FS + No CPU caching', 'No FS + CPU caching', 'No FS + No CPU caching']

for idx, d in enumerate(data):
    ax1.plot(d['Block size'], d['Mean'], label=labels[idx])
ax1.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax1.set_xscale('log')
ax1.set_xlabel('Block size (bytes)')
ax1.set_ylabel('MiB/s')
ax1.set_title('fread() with variable block sizes, 8 MiB file')
ax1.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax1.xaxis.set_major_formatter(formatter)
ax1.set_xticks(df1['Block size'], df1['Block size'])
ax1.legend()

data = [df5, df6, df7, df8]
for idx, d in enumerate(data):
    ax2.plot(d['Block size'], d['Mean'], label=labels[idx])
ax2.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax2.set_xscale('log')
ax2.set_xlabel('Block size (bytes)')
ax2.set_ylabel('MiB/s')
ax2.set_title('fread() with variable block sizes, 100 MiB file')
ax2.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax2.xaxis.set_major_formatter(formatter)
ax2.set_xticks(df5['Block size'], df5['Block size'])
ax2.legend()

data = [df9, df10, df11, df12]
for idx, d in enumerate(data):
    ax3.plot(d['Block size'], d['Mean'], label=labels[idx])
ax3.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax3.set_xscale('log')
ax3.set_xlabel('Block size (bytes)')
ax3.set_ylabel('MiB/s')
ax3.set_title('fread() with variable block sizes, 2.0 GB file')
ax3.axhline(y=3500, color='b', linestyle="dashed", label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax3.xaxis.set_major_formatter(formatter)
ax3.set_xticks(df9['Block size'], df9['Block size'])
ax3.legend()

# %% [markdown]
# ## mmap() + memcpy()

# %%
df1 = pd.read_csv('data/mmapblock_r_fscache_cpucache_8.0MiB_1639681783.csv', header=None)
df1 = df1.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df2 = pd.read_csv('data/mmapblock_r_fscache_nocpucache_8.0MiB_1639681808.csv', header=None)
df2 = df2.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df3 = pd.read_csv('data/mmapblock_r_nofscache_cpucache_8.0MiB_1639681836.csv', header=None)
df3 = df3.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df4 = pd.read_csv('data/mmapblock_r_nofscache_nocpucache_8.0MiB_1639681862.csv', header=None)
df4 = df4.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df5 = pd.read_csv('data/mmapblock_r_fscache_cpucache_100.0MiB_1639681968.csv', header=None)
df5 = df5.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df6= pd.read_csv('data/mmapblock_r_fscache_nocpucache_100.0MiB_1639681999.csv', header=None)
df6 = df6.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df7 = pd.read_csv('data/mmapblock_r_nofscache_cpucache_100.0MiB_1639682061.csv', header=None)
df7 = df7.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df8 = pd.read_csv('data/mmapblock_r_nofscache_nocpucache_100.0MiB_1639682091.csv', header=None)
df8 = df8.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df9 = pd.read_csv('data/mmapblock_r_fscache_cpucache_2.0GiB_1639682199.csv', header=None)
df9 = df9.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df10 = pd.read_csv('data/mmapblock_r_fscache_nocpucache_2.0GiB_1639682324.csv', header=None)
df10 = df10.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df11 = pd.read_csv('data/mmapblock_r_nofscache_cpucache_2.0GiB_1639682456.csv', header=None)
df11 = df11.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df12 = pd.read_csv('data/mmapblock_r_nofscache_nocpucache_2.0GiB_1639682591.csv', header=None)
df12 = df12.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

fig , (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24,8))

data = [df1, df2, df3, df4]
labels = ['FS + CPU caching', 'FS + No CPU caching', 'No FS + CPU caching', 'No FS + No CPU caching']

for idx, d in enumerate(data):
    ax1.plot(d['Block size'], d['Mean'], label=labels[idx])
ax1.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax1.set_xscale('log')
ax1.set_xlabel('Block size (bytes)')
ax1.set_ylabel('MiB/s')
ax1.set_title('mmap() + memcpy() with variable block sizes, 8 MiB file')
ax1.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax1.xaxis.set_major_formatter(formatter)
ax1.set_xticks(df1['Block size'], df1['Block size'])
ax1.legend()

data = [df5, df6, df7, df8]
for idx, d in enumerate(data):
    ax2.plot(d['Block size'], d['Mean'], label=labels[idx])
ax2.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax2.set_xscale('log')
ax2.set_xlabel('Block size (bytes)')
ax2.set_ylabel('MiB/s')
ax2.set_title('mmap() + memcpy() with variable block sizes, 100 MiB file')
ax2.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax2.xaxis.set_major_formatter(formatter)
ax2.set_xticks(df5['Block size'], df5['Block size'])
ax2.legend()

data = [df9, df10, df11, df12]
for idx, d in enumerate(data):
    ax3.plot(d['Block size'], d['Mean'], label=labels[idx])
ax3.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax3.set_xscale('log')
ax3.set_xlabel('Block size (bytes)')
ax3.set_ylabel('MiB/s')
ax3.set_title('mmap() + memcpy() with variable block sizes, 2 GB file')
ax3.axhline(y=3500, color='b', linestyle="dashed", label="Max rated sequential read for system drive (NVMe)")
ax3.set_ylim(ymin=0)
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax3.xaxis.set_major_formatter(formatter)
ax3.set_xticks(df9['Block size'], df9['Block size'])
ax3.legend()

# %% [markdown]
# ## mmap() + custom memcpy()

# %%
df1 = pd.read_csv('data/mmapavx_r_fscache_cpucache_8.0MiB_1639682641.csv', header=None)
df1 = df1.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df2 = pd.read_csv('data/mmapavx_r_fscache_nocpucache_2.0GiB_1639683257.csv', header=None)
df2 = df2.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df3 = pd.read_csv('data/mmapavx_r_nofscache_cpucache_8.0MiB_1639682668.csv', header=None)
df3 = df3.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df4 = pd.read_csv('data/mmapavx_r_nofscache_nocpucache_8.0MiB_1639682690.csv', header=None)
df4 = df4.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df5 = pd.read_csv('data/mmapavx_r_fscache_cpucache_100.0MiB_1639682749.csv', header=None)
df5 = df5.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df6= pd.read_csv('data/mmapavx_r_fscache_nocpucache_100.0MiB_1639682776.csv', header=None)
df6 = df6.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df7 = pd.read_csv('data/mmapavx_r_nofscache_cpucache_2.0GiB_1639683394.csv', header=None)
df7 = df7.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df8 = pd.read_csv('data/mmapavx_r_nofscache_nocpucache_100.0MiB_1639682922.csv', header=None)
df8 = df8.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df9 = pd.read_csv('data/mmapavx_r_fscache_cpucache_2.0GiB_1639683114.csv', header=None)
df9 = df9.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df10 = pd.read_csv('data/mmapavx_r_fscache_nocpucache_2.0GiB_1639683257.csv', header=None)
df10 = df10.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df11 = pd.read_csv('data/mmapavx_r_nofscache_cpucache_2.0GiB_1639683394.csv', header=None)
df11 = df11.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

df12 = pd.read_csv('data/mmapavx2_r_nofscache_nocpucache_2.0GiB_1639685710.csv', header=None)
df12 = df12.rename({0: 'Block size', 26: 'Min', 27: 'Mean', 28: 'Max'}, axis=1)

fig , (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24,8))

data = [df1, df2, df3, df4]
labels = ['FS + CPU caching', 'FS + No CPU caching', 'No FS + CPU caching', 'No FS + No CPU caching']

for idx, d in enumerate(data):
    ax1.plot(d['Block size'], d['Mean'], label=labels[idx])
ax1.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax1.set_xscale('log')
ax1.set_xlabel('Block size (bytes)')
ax1.set_ylabel('MiB/s')
ax1.set_title('mmap() + custom AVX memcpy() with variable block sizes, 8 MiB file')
ax1.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax1.xaxis.set_major_formatter(formatter)
ax1.set_xticks(df1['Block size'], df1['Block size'])
ax1.legend()

data = [df5, df6, df7, df8]
for idx, d in enumerate(data):
    ax2.plot(d['Block size'], d['Mean'], label=labels[idx])
ax2.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax2.set_xscale('log')
ax2.set_xlabel('Block size (bytes)')
ax2.set_ylabel('MiB/s')
ax2.set_title('mmap() + custom AVX memcpy() with variable block sizes, 100 MiB file')
ax2.axhline(y=3500, color='b', linestyle="dashed",label="Max rated sequential read for system drive (NVMe)")
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax2.xaxis.set_major_formatter(formatter)
ax2.set_xticks(df5['Block size'], df5['Block size'])
ax2.legend()

data = [df9, df10, df11, df12]
for idx, d in enumerate(data):
    ax3.plot(d['Block size'], d['Mean'], label=labels[idx])
ax3.set_xticks(df1['Block size'], df1['Block size'], rotation="vertical")
ax3.set_xscale('log')
ax3.set_xlabel('Block size (bytes)')
ax3.set_ylabel('MiB/s')
ax3.set_title('mmap() + custom AVX memcpy() with variable block sizes, 2 GB file')
ax3.axhline(y=3500, color='b', linestyle="dashed", label="Max rated sequential read for system drive (NVMe)")
ax3.set_ylim(ymin=0)
formatter = ScalarFormatter()
formatter.set_scientific(False)
ax3.xaxis.set_major_formatter(formatter)
ax3.set_xticks(df9['Block size'], df9['Block size'])
ax3.legend()
